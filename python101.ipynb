# %% [markdown]
# <a href="https://colab.research.google.com/github/trannguyenanhthi10-sudo/thitran.ueh/blob/main/python101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat first.py
print ("-"*50)
print ('Interpret...')
# %run first.py
# Out:
# cat: first.py: No such file or directory
# --------------------------------------------------
# Interpret...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.11/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'first.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipython-input-2320848693.py in <cell line: 0>()
#       2 print ("-"*50)
# ...

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
# comment
'''
comment
'''
print('comment')
# Out:
# comment

# %%
# indent
score = 80
if score >= 60:
   print("Pass")
   pass # dummy
# Out:
# Pass

# %%
x = 2
y = x + 1
print(f'x = {x}, y = {y}')
print ('x = %d, y = %d'%(x,y))
